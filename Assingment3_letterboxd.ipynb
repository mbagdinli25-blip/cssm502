# %%
pip install scrapy
# Out:
# Requirement already satisfied: scrapy in /opt/anaconda3/lib/python3.13/site-packages (2.12.0)
# Requirement already satisfied: Twisted>=21.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (24.11.0)
# Requirement already satisfied: cryptography>=37.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (44.0.1)
# Requirement already satisfied: cssselect>=0.9.1 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (25.0.0)
# Requirement already satisfied: queuelib>=1.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service_identity>=18.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (24.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (7.1.1)
# Requirement already satisfied: protego>=0.1.15 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (0.4.0)
# Requirement already satisfied: itemadapter>=0.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (24.2)
# Requirement already satisfied: tldextract in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (5.1.2)
# Requirement already satisfied: lxml>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (5.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (0.7.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /opt/anaconda3/lib/python3.13/site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography>=37.0.0->scrapy) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography>=37.0.0->scrapy) (2.21)
# Requirement already satisfied: jmespath>=0.9.5 in /opt/anaconda3/lib/python3.13/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from service_identity>=18.1.0->scrapy) (24.3.0)
# Requirement already satisfied: pyasn1 in /opt/anaconda3/lib/python3.13/site-packages (from service_identity>=18.1.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in /opt/anaconda3/lib/python3.13/site-packages (from service_identity>=18.1.0->scrapy) (0.2.8)
# Requirement already satisfied: automat>=24.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from Twisted>=21.7.0->scrapy) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in /opt/anaconda3/lib/python3.13/site-packages (from Twisted>=21.7.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from Twisted>=21.7.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from Twisted>=21.7.0->scrapy) (24.7.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from Twisted>=21.7.0->scrapy) (4.12.2)
# Requirement already satisfied: idna>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from hyperlink>=17.1.1->Twisted>=21.7.0->scrapy) (3.7)
# Requirement already satisfied: setuptools>=61.0 in /opt/anaconda3/lib/python3.13/site-packages (from incremental>=24.7.0->Twisted>=21.7.0->scrapy) (72.1.0)
# Requirement already satisfied: requests>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from tldextract->scrapy) (2.32.3)
# Requirement already satisfied: requests-file>=1.4 in /opt/anaconda3/lib/python3.13/site-packages (from tldextract->scrapy) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /opt/anaconda3/lib/python3.13/site-packages (from tldextract->scrapy) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.1.0->tldextract->scrapy) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scrapy import Selector
import requests

# %% [markdown]
# hocam merhaba, scrapelemek istediğim sayfa letterboxd.com
#
# sadece film içerikleri etrafında bir seçme gerçekleştireceğim kişilerin verilerine ya da kişisel listelerine erişmeden sadece katalog üzerinden bir çekim gerçekleştireceğim
#
# https://letterboxd.com/directors linkleri üzerinden yönetmenlerin filmlerinden listeler oluşturmaya çalışacağım
#
# robots.txt file'ını inceledim ve yönetmenler sekmesinde bir kısıtlama koymamışlar. bu sebeple sitede trafik oluşturmadan verileri çekmeyi deneyeceğim
#
# ***See http://www.robotstxt.org/wc/norobots.html for documentation on how to use the robots.txt file***
#
#  Dark Visitors robots.txt from https://darkvisitors.com/robots-txt-builder
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/ai2bot
#
# User-agent: AI2Bot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/applebot-extended
#
# User-agent: Applebot-Extended
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/bytespider
#
# User-agent: Bytespider
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/ccbot
#
# User-agent: CCBot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/claudebot
#
# User-agent: ClaudeBot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/diffbot
#
# User-agent: Diffbot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/cohere-training-data-crawler
#
# User-agent: cohere-training-data-crawler
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/cotoyogi
#
# User-agent: Cotoyogi
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/datenbank-crawler
#
# User-agent: Datenbank Crawler
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/facebookbot
#
# User-agent: FacebookBot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/factset-spyderbot
#
# User-agent: Factset_spyderbot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/google-extended
#
# User-agent: Google-Extended
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/gptbot
#
# User-agent: GPTBot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/icc-crawler
#
# User-agent: ICC-Crawler
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/kangaroo-bot
#
# User-agent: Kangaroo Bot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/meta-externalagent
#
# User-agent: Meta-ExternalAgent
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/netestate-imprint-crawler
#
# User-agent: netEstate Imprint Crawler
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/omgili
#
# User-agent: omgili
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/pangubot
#
# User-agent: PanguBot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/petalbot
#
# User-agent: PetalBot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/semrushbot-ocob
#
# User-agent: SemrushBot-OCOB
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/timpibot
#
# User-agent: Timpibot
# Disallow: /
#
#  AI Data Scraper
#  https://darkvisitors.com/agents/webzio-extended
#
# User-agent: Webzio-Extended
# Disallow: /
#
#  All other crawlers
# User-agent: *
# Disallow: /*/by/*                     # sorting options
# Disallow: /*/popular/this/*           # popularity sorting options
# Disallow: /*/on/*                     # availability options
# Disallow: /*/tag/*                    # Members? tag lists
# Disallow: /*/genre/*                  # Films by genre
# Disallow: /*/country/*                # Films by country
# Disallow: /*/language/*               # Films by language
# Disallow: /*/decade/*                 # Films by decade
# Disallow: /films/year/*               # Films by year
# Disallow: /films/*/year/*             # Films by year
# Disallow: /films/*/size/large/*       # Films with large posters (and therefore stats)

# %% [markdown]
# # sitenin yapısı
#
# veritabanı içerisinde tüm türler, tüm ülkeler ve tüm yıllara göre filtreleyebileceğimiz 417 sayfalık her sayfada 24 film olan bir katalog

# %%
from scrapy import Selector

import requests

url= 'https://letterboxd.com'
html=requests.get(url).content
sel=Selector(text=html)

# %%
print(len(sel.xpath("//*")))
# Out:
# 1596

# %%
html
# Out:
# b'<!DOCTYPE html><html lang="tr"><head><meta charSet="utf-8" data-next-head=""/><meta name="viewport" content="width=device-width" data-next-head=""/><title data-next-head="">MUBI Veritaban\xc4\xb1nda olan t\xc3\xbcm filmler</title><link href="/favicon.ico" rel="icon" type="image/x-icon" data-next-head=""/><meta content="app-id=626148774" name="apple-itunes-app" data-next-head=""/><link href="/apple-touch-icon.png?ver=2" rel="apple-touch-icon" data-next-head=""/><meta name="description" content="MUBI Veritaban\xc4\xb1nda olan t\xc3\xbcm filmler" data-next-head=""/><link rel="canonical" href="https://mubi.com/tr/films?sort=popularity_quality_score" data-next-head=""/><meta content="follow, index" name="robots" data-next-head=""/><link rel="preload" href="https://assets.mubicdn.net/static/fonts/RiformaLLWeb-Medium.woff2" as="font" crossorigin="anonymous"/><link rel="preload" href="https://assets.mubicdn.net/static/fonts/RiformaLLWeb-Regular.woff2" as="font" crossorigin="anonymous"/><link rel="preload" href="https://assets.mubicdn.net/static/fonts/RiformaLLWeb-Bold.woff2" as="font" crossorigin="anonymous"/><link rel="preload" href="https://assets.mubicdn.net/static/fonts/RiformaLLWeb-Italic.woff2" as="font" crossorigin="anonymous"/><meta name="google-site-verification" content="iZY7BeaCykgtLfBovCb6ala6DsrhSEbIpb9SU0IYM4o"/><link rel="preload" href="https://assets.mubicdn.net/_next/static/css/9a3ff8d7ce992ad4.css" as="style"/><meta name="sentry-trace" content="7c1a5793a7759588adfcbb5e42104491-a3a5fd771608c118-0"/><meta name="baggage" content="sentry-environment=production,sentry-release=180fe0450b1f3e780c3597a8def4ecd63e487344,sentry-public_key=3b8c3e6654eafb37822681af4549d1bd,sentry-trace_id=7c1a5793a7759588adfcbb5e42104491,sentry-org_id=535082,sentry-sampled=false,sentry-sample_rand=0.16159507944169338,sentry-sample_rate=0"/><script id="initialise-google-consent" data-nscript="beforeInteractive">\n              window.dataLayer = window.dataLayer || [];\n              function gtag() {\n                dataLayer.push(arguments);\n              }\n              gtag("consent", "default", {\n                ad_storage: "denied",\n                ad_user_data: "denied", \n                ad_personalization: "denied",\n                analytics_storage: "denied",\n                functionality_storage: "denied",\n                personalization_storage: "denied",\n                security_storage: "granted",\n                wait_for_update: 2000,\n              });\n              gtag("set", "ads_data_redaction", true);\n              gtag("set", "url_passthrough", true);\n            </script><link rel="stylesheet" href="https://assets.mubicdn.net/_next/static/css/9a3ff8d7ce992ad4.css" data-n-g=""/><noscript data-n-css=""></noscript><script defer="" noModule="" src="https://assets.mubicdn.net/_next/static/chunks/polyfills-42372ed130431b0a.js"></script><script src="https://cdn-cookieyes.com/client_data/557d88e3cc18545818539070/script.js" defer="" data-nscript="beforeInteractive"></script><script src="https://assets.mubicdn.net/_next/static/chunks/webpack-fb1780b86243f25e.js" defer=""></script><script src="https://assets.mubicdn.net/_next/static/chunks/framework-1b0b7355cd814654.js" defer=""></script><script src="https://assets.mubicdn.net/_next/static/chunks/main-2add90d28c4b4c27.js" defer=""></script><script src="https://assets.mubicdn.net/_next/static/chunks/pages/_app-2caedf55b06d84e4.js" defer=""></script><script src="https://assets.mubicdn.net/_next/static/chunks/63111-e6aab2d25d62c5e9.js" defer=""></script><script src="https://assets.mubicdn.net/_next/static/chunks/70068-e67eae7fb2504721.js" defer=""></script><script src="https://assets.mubicdn.net/_next/static/chunks/92349-c33c6609bf9a0487.js" defer=""></script><script src="https://assets.mubicdn.net/_next/static/chunks/41644-f18e8394474962a2.js" defer=""></script><script src="https://assets.mubicdn.net/_next/static/chunks/56854-1cd3cac4326ee665.js" defer=""></script><script ...

# %% [markdown]
# İlk iş olarak yönetmenlerin sayfalarındaki filmlerin isimlerinden bir liste oluşturmaya çalışıp daha sonrasında yönetmen sayfasında bulunan ** decade, genre, service ve sort by popularity ** filtreleriyle birbirinden farklı örnekler çekmeye çalışacağım.
#
# En son da verilmiş bir yönetmen listesinden bana farklı filtrelerle filmleri çekmesini isteyeceğim

# %%
#ilk olarak Agnès Varda'nın filmlerini çekeceğim
url='https://letterboxd.com/director/agnes-varda/'
html= requests.get(url).content
sel=Selector(text=html)
print("filtrelenmiş bu kadar veri buldun:", len(sel.xpath("//*")))
# Out:
# filtrelenmiş bu kadar veri buldun: 1441

# %%
html
# Out:
# b'\n\n<!DOCTYPE html>\n\n<html id="html" lang="en" class="context-client-unknown no-mobile no-js">\n<head>\n\t<meta charset="UTF-8" />\n\t\n\t\n\t\t\t\n\t\t\n\t<meta name="viewport" content="width=1024" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n\t<meta name="description" content="Films directed by Agn\xc3\xa8s Varda" />\n\t\n\t\n\t<meta property="og:url" content="https://letterboxd.com/director/agnes-varda/" />\n\t<meta property="og:title" content="Films directed by Agn\xc3\xa8s Varda" />\n\t<meta property="og:description" content="Films directed by Agn\xc3\xa8s Varda" />\n\t<meta property="og:image" content="https://s.ltrbxd.com/static/img/default-share-7md9L34t.png" />\n\t<meta property="fb:app_id" content="173683136069040" />\n\t\n\t<meta name="application-name" content="Letterboxd" />\n\t<meta name="theme-color" content="#14181C" />\n\t<meta name="msapplication-TileColor" content="#445566" />\n\t<meta name="apple-itunes-app" content="app-id=1054271011, affiliate-data=11l5KW, app-argument=https://letterboxd.com/director/agnes-varda/" />\n\t<meta name="mobile-web-app-capable" content="yes" />\n\n\t<title>&lrm;Films directed by Agn\xc3\xa8s Varda &bull; Letterboxd</title>\n\t<script>\n\t\t\n\t\t((r, n) => {\n\t\t\tr.dataset.useragent = n.userAgent\n\t\t\tr.dataset.platform = n.platform\n\t\t})(document.documentElement, navigator)\n\n\t\tvar isMobile = false,\n\t\t\tisMobileOptimised = true,\n\t\t\trenderMobile = false,\n\t\t\tuseStaticFonts = false,\n\t\t\tdisableFrameProtection = false,\n\t\t\tbaseURL = \'\',\n\t\t\tstaticAssetBaseURL = \'https://s.ltrbxd.com/\'.slice(0, -1),\n\t\t\tsuccessMessages = [],\n\t\t\terrorMessages = [],\n\t\t\tstickyMessages = [],\n\t\t\tglobals = {\n\t\t\tautoAddFilm: false\n\t\t\t\t, spinners: {\n\t\t\t\t\tajax_242d35: \'https://s.ltrbxd.com/static/img/spinner-dark-2x-BA9SNVrD.gif\',\n\t\t\t\t\tspinner_12_2C3641: \'https://s.ltrbxd.com/static/img/spinner-dark-2x-BA9SNVrD.gif\',\n\t\t\t\t\tspinner_14_20272f: \'https://s.ltrbxd.com/static/img/spinner-dark-2x-BA9SNVrD.gif\',\n\t\t\t\t\tspinner_16_161B21: \'https://s.ltrbxd.com/static/img/spinner-dark-2x-BA9SNVrD.gif\'\n\t\t\t\t}\n\t\t\t},\n\t\t\tsupermodelCSRF = "",\n\t\t\tgRecaptchaKey = \'6Le3mMIUAAAAAEXbwZ7M1R5jEv0V5xbvj7bgXq2g\',\n\t\t\tgeolocation = {\n\t\t\t\tcountry: ""\n\t\t\t},\n\t\t\tperson = {\n\t\t\t\tusername: ""\n\t\t\t\t, loggedIn: false\n\t\t\t\t\n\t\t\t\t, showAds: true\n\t\t\t\t, role: "guest"\n\t\t\t\t, hasExtendedServiceFilters: false\n\t\t\t\t, canBulkAddToLists: false\n\t\t\t\t, canFilterOwned: false\n\t\t\t\t, hasHqRole: false\n\t\t\t\t, canHaveHqDashboard: false\n\t\t\t\t, hasMemberStatistics: false\n\t\t\t\t, blockedMembers: []\n\t\t\t\t, showAdultContent: false\n\t\t\t\t, validated: null\n\t\t\t\t, trusted: false\n\t\t\t\t, hasBlocked : function(member) { for (var i = 0; i !== person.blockedMembers.length; i++) {if (person.blockedMembers[i] === member) return true;} return false; }\n\t\t\t\t, viewingTags: []\n\t\t\t\t, hasMoreTags: true\n\t\t\t\t, getCustomPoster : function(uid) { return null; }\n\t\t\t\t, getCustomBackdrop : function(uid) { return null; }\n\t\t\t},\n\t\t\tdisableAds = false,\n\t\t\tanalytic_params = {};\n\t\t\n\t\t\nsupermodelCSRF = \'9028ebd4a13e16335ded\'; geolocation.country = \'TR\'; analytic_params[\'user_type\'] = \'Visitor\';\n\n\t</script>\n\t\n\t<script>\n\t\twindow.dataLayer = window.dataLayer || [];\n\t\twindow.gtag = window.gtag || function () {\n\t\t\tdataLayer.push(arguments);\n\t\t};\n\t\tfunction ga() {}\n\t</script>\n\n\t<script async src="https://www.googletagmanager.com/gtag/js?id=G-D3ECBB4D7L"></script>\n\t<script>\n\t\twindow.dataLayer = window.dataLayer || [];\n\t\twindow.gtag = window.gtag || function () {\n\t\t\tdataLayer.push(arguments);\n\t\t};\n\t\tgtag(\'js\', new Date());\n\t\n\t\tanalytic_params[\'template\'] = \'/object/filmcontributor\';\n\t\t\n\t\t\n\n\t\tif (analytic_params.member_type) {\n\t\t\tgtag(\'set\', \'user_properties\', { \n\t\t\t\t ...

# %% [markdown]
# Hocam siteyi biraz kurcalardıktan sonra isimleri hem sırasız listenin(ul) kendisinden hem de liste maddesinin içindeki konteynerdaki (li/div) element attributelarından çekebileceğimi farkettim.

# %%
xpath_for_titles_of_works='//*[@id="content"]/div/div/section/div[2]/ul/li/div/@data-item-name'
titles_of_works=sel.xpath(xpath_for_titles_of_works).extract()
titles_of_works
# Out:
# ['Cléo from 5 to 7 (1962)',
#  'Vagabond (1985)',
#  'Le Bonheur (1965)',
#  'The Gleaners and I (2000)',
#  'Faces Places (2017)',
#  'The Beaches of Agnès (2008)',
#  "One Sings, the Other Doesn't (1977)",
#  'Black Panthers (1968)',
#  'La Pointe Courte (1955)',
#  'Jane B. by Agnès V. (1988)',
#  'Varda by Agnès (2019)',
#  'Along the Coast (1958)',
#  'Uncle Yanco (1967)',
#  'Hello Cubans (1963)',
#  'Daguerréotypes (1975)',
#  'Jacquot de Nantes (1991)',
#  'One Hundred and One Nights (1995)',
#  'Women Reply (1975)',
#  'Mur Murs (1981)',
#  'Kung-Fu Master! (1988)',
#  'Lions Love (1969)',
#  'Diary of a Pregnant Woman (1958)',
#  'Far from Vietnam (1967)',
#  'Documenteur (1981)',
#  'The Creatures (1966)',
#  'Fiancés on the Bridge (1962)',
#  'Ulysse (1983)',
#  'The Pleasure of Love in Iran (1976)',
#  "You've Got Beautiful Stairs, You Know... (1986)",
#  'The Young Girls Turn 25 (1993)',
#  'Agnès Varda: From Here to There (2011)',
#  'Tribute to Zgougou the Cat (2002)',
#  'The So-Called Caryatids (1984)',
#  'The Gleaners and I: Two Years Later (2002)',
#  'O Seasons, O Castles (1958)',
#  'Pier Paolo Pasolini - Agnès Varda - New York - 1967 (2022)',
#  'The World of Jacques Demy (1995)',
#  'The Vanishing Lion (2003)',
#  'Les 3 Boutons (2015)',
#  'Elsa the Rose (1966)',
#  'Seven Rooms, Kitchen, Bathroom, for Sale (1984)',
#  'Ydessa, the Bears and etc. (2004)',
#  'Nausicaa (1971)',
#  'Cléo from 5 to 7: Remembrances and Anecdotes (2005)',
#  'One Minute for One Image (1983)',
#  "In Chris Marker's Studio (2011)",
#  'The Little Story of Gwen from French Brittany (2008)',
#  'Rue Daguerre in 2005 (2005)',
#  'Vagabond: Remembrances, Interviews, Notes and Comments (2003)',
#  'Henri Langlois vu par... (2014)',
#  'Some Widows of Noirmoutier (2006)',
#  '20 Little Films (2012)',
#  'More So-called Caryatids (2005)',
#  'The Story of an Old Lady (2003)',
#  'Cinévardaphoto (2004)',
#  'Christmas Carole (1966)',
#  'Agnès Tells a Sad and Happy Story (2008)',
#  'Souvenirs and Evocations (2008)',
#  'Un salut à Henri Langlois (2014)',
#  'The Children of Museum (1964)',
#  "La Cocotte d'azur (1958)",
#  'La Mélangite (1960)',
#  'The 3 Lives of Agnès (2012)',
#  'Two Street Artists (2012)',
#  'Bord de mer (2009)',
#  'Bread, Painting, Accordion (2005)',
#  'Daguerreotypes, Photographics Objects (2005)',
#  'The Music Festival (2005)',
#  'Daguerre-plage (2008)',
#  'Musique et Travellings (2003)',
#  "Propos sur 'Le bonheur' (2006)",
#  'Un divertissement et Michel Piccoli (2004)',
#  'a Nathalie Sarraute (1986)',
#  'Le Bonheur? Réponses des Fontenaisiens (2006)',
#  'Les deux femmes du Bonheur (2006)',
#  'Bonheur: nom propre ou concept (2006)',
#  'Jean-Claude Drouot revient à Fontenay-aux-Roses et parle du film tourné en 1964 (2006)',
#  'Trapézistes et voltigeurs (2008)']

# %%
xpath_for_titles_of_works='//*[@id="content"]/div/div/section/div[2]/ul/li[@title]/@title'
titles_of_works=sel.xpath(xpath_for_titles_of_works).getall()
titles_of_works
# Out:
# ['Cléo from 5 to 7 (1962)',
#  'Vagabond (1985)',
#  'Le Bonheur (1965)',
#  'The Gleaners and I (2000)',
#  'Faces Places (2017)',
#  'The Beaches of Agnès (2008)',
#  "One Sings, the Other Doesn't (1977)",
#  'Black Panthers (1968)',
#  'La Pointe Courte (1955)',
#  'Jane B. by Agnès V. (1988)',
#  'Varda by Agnès (2019)',
#  'Along the Coast (1958)',
#  'Uncle Yanco (1967)',
#  'Hello Cubans (1963)',
#  'Daguerréotypes (1975)',
#  'Jacquot de Nantes (1991)',
#  'One Hundred and One Nights (1995)',
#  'Women Reply (1975)',
#  'Mur Murs (1981)',
#  'Kung-Fu Master! (1988)',
#  'Lions Love (1969)',
#  'Diary of a Pregnant Woman (1958)',
#  'Far from Vietnam (1967)',
#  'Documenteur (1981)',
#  'The Creatures (1966)',
#  'Fiancés on the Bridge (1962)',
#  'Ulysse (1983)',
#  'The Pleasure of Love in Iran (1976)',
#  "You've Got Beautiful Stairs, You Know... (1986)",
#  'The Young Girls Turn 25 (1993)',
#  'Agnès Varda: From Here to There (2011)',
#  'Tribute to Zgougou the Cat (2002)',
#  'The So-Called Caryatids (1984)',
#  'The Gleaners and I: Two Years Later (2002)',
#  'O Seasons, O Castles (1958)',
#  'Pier Paolo Pasolini - Agnès Varda - New York - 1967 (2022)',
#  'The World of Jacques Demy (1995)',
#  'The Vanishing Lion (2003)',
#  'Les 3 Boutons (2015)',
#  'Elsa the Rose (1966)',
#  'Seven Rooms, Kitchen, Bathroom, for Sale (1984)',
#  'Ydessa, the Bears and etc. (2004)',
#  'Nausicaa (1971)',
#  'Cléo from 5 to 7: Remembrances and Anecdotes (2005)',
#  'One Minute for One Image (1983)',
#  "In Chris Marker's Studio (2011)",
#  'The Little Story of Gwen from French Brittany (2008)',
#  'Rue Daguerre in 2005 (2005)',
#  'Vagabond: Remembrances, Interviews, Notes and Comments (2003)',
#  'Henri Langlois vu par... (2014)',
#  'Some Widows of Noirmoutier (2006)',
#  '20 Little Films (2012)',
#  'More So-called Caryatids (2005)',
#  'The Story of an Old Lady (2003)',
#  'Cinévardaphoto (2004)',
#  'Christmas Carole (1966)',
#  'Agnès Tells a Sad and Happy Story (2008)',
#  'Souvenirs and Evocations (2008)',
#  'Un salut à Henri Langlois (2014)',
#  'The Children of Museum (1964)',
#  "La Cocotte d'azur (1958)",
#  'La Mélangite (1960)',
#  'The 3 Lives of Agnès (2012)',
#  'Two Street Artists (2012)',
#  'Bord de mer (2009)',
#  'Bread, Painting, Accordion (2005)',
#  'Daguerreotypes, Photographics Objects (2005)',
#  'The Music Festival (2005)',
#  'Daguerre-plage (2008)',
#  'Musique et Travellings (2003)',
#  "Propos sur 'Le bonheur' (2006)",
#  'Un divertissement et Michel Piccoli (2004)',
#  'a Nathalie Sarraute (1986)',
#  'Le Bonheur? Réponses des Fontenaisiens (2006)',
#  'Les deux femmes du Bonheur (2006)',
#  'Bonheur: nom propre ou concept (2006)',
#  'Jean-Claude Drouot revient à Fontenay-aux-Roses et parle du film…',
#  'Trapézistes et voltigeurs (2008)']

# %% [markdown]
# Ayrıca web sitesi link üzerinden yönlendirdiği için filme, filmlerin kendi linkleri de HTML'in içinde bulunuyor fakat burdaki a elementi sonradan javascript ile eklenmis o sebeple requests ve selectorle çekemiyorum ama yapıyı izlediğim zaman itemin ismini bulabildim
#
#
# //*[@id="content"]/div/div/section/div[2]/ul/li[1]/div/div/a
#
# //*[@id="content"]/div/div/section/div[2]/ul/li[2]/div/div/a
#
# > //*[@id="content"]/div/div/section/div[2]/ul/li/div/div/a
#
# önceki div elemanını çekince a'nın

# %%
xpath_for_links_of_works='//*[@id="content"]/div/div/section/div[2]/ul/li/div/div//*'
links_of_works=sel.xpath(xpath_for_links_of_works).extract()
links_of_works
# Out:
# ['<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Cléo from 5 to 7">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Vagabond">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Le Bonheur">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Gleaners and I">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Faces Places">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Beaches of Agnès">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="One Sings, the Other Doesn\'t">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Black Panthers">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="La Pointe Courte">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Jane B. by Agnès V.">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Varda by Agnès">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Along the Coast">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Uncle Yanco">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Hello Cubans">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Daguerréotypes">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Jacquot de Nantes">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="One Hundred and One Nights">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Women Reply">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Mur Murs">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Kung-Fu Master!">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Lions Love">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Diary of a Pregnant Woman">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Far from Vietnam">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Documenteur">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Creatures">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Fiancés on the Bridge">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Ulysse">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Pleasure of Love in Iran">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="You\'ve Got Beautiful Stairs, You Know...">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Young Girls Turn 25">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Agnès Varda: From Here to There">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Tribute to Zgougou the Cat">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The So-Called Caryatids">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Gleaners and I: Two Years Later">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="O Seasons, O Castles">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Pier Paolo Pasolini - Agnès Varda - New York - 1967">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The World of Jacques Demy">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Vanishing Lion">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Les 3 Boutons">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Elsa the Rose">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Seven Rooms, Kitchen, Bathroom, for Sale">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Ydessa, the Bears and etc.">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Nausicaa">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Cléo from 5 to 7: Remembrances and Anecdotes">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="One Minute for One Image">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="In Chris Marker\'s Studio">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Little Story of Gwen from French Brittany">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Rue Daguerre in 2005">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Vagabond: Remembrances, Interviews, Notes and Comments">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Henri Langlois vu par...">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Some Widows of Noirmoutier">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="20 Little Films">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="More So-called Caryatids">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Story of an Old Lady">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Cinévardaphoto">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Christmas Carole">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Agnès Tells a Sad and Happy Story">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Souvenirs and Evocations">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Un salut à Henri Langlois">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Children of Museum">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="La Cocotte d\'azur">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="La Mélangite">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The 3 Lives of Agnès">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Two Street Artists">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Bord de mer">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Bread, Painting, Accordion">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Daguerreotypes, Photographics Objects">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="The Music Festival">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Daguerre-plage">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Musique et Travellings">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Propos sur \'Le bonheur\'">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Un divertissement et Michel Piccoli">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="a Nathalie Sarraute">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Le Bonheur? Réponses des Fontenaisiens">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Les deux femmes du Bonheur">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Bonheur: nom propre ou concept">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Jean-Claude Drouot revient à Fontenay-aux-Roses et parle du film tourné en 1964">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>',
#  '<img src="https://s.ltrbxd.com/static/img/empty-poster-150-DtnLDE3k.png" class="image" width="150" height="225" alt="Trapézistes et voltigeurs">',
#  '<span class="frame"><span class="frame-title"></span></span>',
#  '<span class="frame-title"></span>']

# %% [markdown]
# HTML kodunu decode edip baktığım zaman
#
# ***data-item-name="Cléo from 5 to 7 (1962)" data-item-slug="cleo-from-5-to-7" data-item-link="/film/cleo-from-5-to-7/"***
#
# slug ve linkin bu attributelarda saklandığını öğrendim.
#
# HTML kodunda da filmler li ile ayrıldığı için listeden sonraki kısımda bu itemi aradım

# %%
html.decode()
# Out:
# '\n\n<!DOCTYPE html>\n\n<html id="html" lang="en" class="context-client-unknown no-mobile no-js">\n<head>\n\t<meta charset="UTF-8" />\n\t\n\t\n\t\t\t\n\t\t\n\t<meta name="viewport" content="width=1024" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n\t<meta name="description" content="Films directed by Agnès Varda" />\n\t\n\t\n\t<meta property="og:url" content="https://letterboxd.com/director/agnes-varda/" />\n\t<meta property="og:title" content="Films directed by Agnès Varda" />\n\t<meta property="og:description" content="Films directed by Agnès Varda" />\n\t<meta property="og:image" content="https://s.ltrbxd.com/static/img/default-share-7md9L34t.png" />\n\t<meta property="fb:app_id" content="173683136069040" />\n\t\n\t<meta name="application-name" content="Letterboxd" />\n\t<meta name="theme-color" content="#14181C" />\n\t<meta name="msapplication-TileColor" content="#445566" />\n\t<meta name="apple-itunes-app" content="app-id=1054271011, affiliate-data=11l5KW, app-argument=https://letterboxd.com/director/agnes-varda/" />\n\t<meta name="mobile-web-app-capable" content="yes" />\n\n\t<title>&lrm;Films directed by Agnès Varda &bull; Letterboxd</title>\n\t<script>\n\t\t\n\t\t((r, n) => {\n\t\t\tr.dataset.useragent = n.userAgent\n\t\t\tr.dataset.platform = n.platform\n\t\t})(document.documentElement, navigator)\n\n\t\tvar isMobile = false,\n\t\t\tisMobileOptimised = true,\n\t\t\trenderMobile = false,\n\t\t\tuseStaticFonts = false,\n\t\t\tdisableFrameProtection = false,\n\t\t\tbaseURL = \'\',\n\t\t\tstaticAssetBaseURL = \'https://s.ltrbxd.com/\'.slice(0, -1),\n\t\t\tsuccessMessages = [],\n\t\t\terrorMessages = [],\n\t\t\tstickyMessages = [],\n\t\t\tglobals = {\n\t\t\tautoAddFilm: false\n\t\t\t\t, spinners: {\n\t\t\t\t\tajax_242d35: \'https://s.ltrbxd.com/static/img/spinner-dark-2x-BA9SNVrD.gif\',\n\t\t\t\t\tspinner_12_2C3641: \'https://s.ltrbxd.com/static/img/spinner-dark-2x-BA9SNVrD.gif\',\n\t\t\t\t\tspinner_14_20272f: \'https://s.ltrbxd.com/static/img/spinner-dark-2x-BA9SNVrD.gif\',\n\t\t\t\t\tspinner_16_161B21: \'https://s.ltrbxd.com/static/img/spinner-dark-2x-BA9SNVrD.gif\'\n\t\t\t\t}\n\t\t\t},\n\t\t\tsupermodelCSRF = "",\n\t\t\tgRecaptchaKey = \'6Le3mMIUAAAAAEXbwZ7M1R5jEv0V5xbvj7bgXq2g\',\n\t\t\tgeolocation = {\n\t\t\t\tcountry: ""\n\t\t\t},\n\t\t\tperson = {\n\t\t\t\tusername: ""\n\t\t\t\t, loggedIn: false\n\t\t\t\t\n\t\t\t\t, showAds: true\n\t\t\t\t, role: "guest"\n\t\t\t\t, hasExtendedServiceFilters: false\n\t\t\t\t, canBulkAddToLists: false\n\t\t\t\t, canFilterOwned: false\n\t\t\t\t, hasHqRole: false\n\t\t\t\t, canHaveHqDashboard: false\n\t\t\t\t, hasMemberStatistics: false\n\t\t\t\t, blockedMembers: []\n\t\t\t\t, showAdultContent: false\n\t\t\t\t, validated: null\n\t\t\t\t, trusted: false\n\t\t\t\t, hasBlocked : function(member) { for (var i = 0; i !== person.blockedMembers.length; i++) {if (person.blockedMembers[i] === member) return true;} return false; }\n\t\t\t\t, viewingTags: []\n\t\t\t\t, hasMoreTags: true\n\t\t\t\t, getCustomPoster : function(uid) { return null; }\n\t\t\t\t, getCustomBackdrop : function(uid) { return null; }\n\t\t\t},\n\t\t\tdisableAds = false,\n\t\t\tanalytic_params = {};\n\t\t\n\t\t\nsupermodelCSRF = \'9028ebd4a13e16335ded\'; geolocation.country = \'TR\'; analytic_params[\'user_type\'] = \'Visitor\';\n\n\t</script>\n\t\n\t<script>\n\t\twindow.dataLayer = window.dataLayer || [];\n\t\twindow.gtag = window.gtag || function () {\n\t\t\tdataLayer.push(arguments);\n\t\t};\n\t\tfunction ga() {}\n\t</script>\n\n\t<script async src="https://www.googletagmanager.com/gtag/js?id=G-D3ECBB4D7L"></script>\n\t<script>\n\t\twindow.dataLayer = window.dataLayer || [];\n\t\twindow.gtag = window.gtag || function () {\n\t\t\tdataLayer.push(arguments);\n\t\t};\n\t\tgtag(\'js\', new Date());\n\t\n\t\tanalytic_params[\'template\'] = \'/object/filmcontributor\';\n\t\t\n\t\t\n\n\t\tif (analytic_params.member_type) {\n\t\t\tgtag(\'set\', \'user_properties\', { \n\t\t\t\tmember_type: analytic_params. ...

# %%
xpath_for_links_of_works='//*[@id="content"]/div/div/section/div[2]/ul/li//@data-item-link'
links_of_works=sel.xpath(xpath_for_links_of_works).extract()
links_of_works
# Out:
# ['/film/cleo-from-5-to-7/',
#  '/film/vagabond/',
#  '/film/happiness-1965/',
#  '/film/the-gleaners-and-i/',
#  '/film/faces-places/',
#  '/film/the-beaches-of-agnes/',
#  '/film/one-sings-the-other-doesnt/',
#  '/film/black-panthers/',
#  '/film/la-pointe-courte/',
#  '/film/jane-b-by-agnes-v/',
#  '/film/varda-by-agnes/',
#  '/film/along-the-coast/',
#  '/film/uncle-yanco/',
#  '/film/hello-cubans/',
#  '/film/daguerreotypes/',
#  '/film/jacquot-de-nantes/',
#  '/film/one-hundred-and-one-nights/',
#  '/film/women-reply/',
#  '/film/mur-murs/',
#  '/film/kung-fu-master/',
#  '/film/lions-love/',
#  '/film/diary-of-a-pregnant-woman/',
#  '/film/far-from-vietnam/',
#  '/film/documenteur/',
#  '/film/the-creatures/',
#  '/film/fiances-on-the-bridge/',
#  '/film/ulysse/',
#  '/film/the-pleasure-of-love-in-iran/',
#  '/film/youve-got-beautiful-stairs-you-know/',
#  '/film/the-young-girls-turn-25/',
#  '/film/agnes-varda-from-here-to-there/',
#  '/film/tribute-to-zgougou-the-cat/',
#  '/film/the-so-called-caryatids/',
#  '/film/the-gleaners-and-i-two-years-later/',
#  '/film/o-seasons-o-castles/',
#  '/film/pier-paolo-pasolini-agnes-varda-new-york-1967/',
#  '/film/the-world-of-jacques-demy/',
#  '/film/the-vanishing-lion/',
#  '/film/les-3-boutons/',
#  '/film/elsa-the-rose/',
#  '/film/seven-rooms-kitchen-bathroom-for-sale/',
#  '/film/ydessa-the-bears-and-etc/',
#  '/film/nausicaa/',
#  '/film/cleo-from-5-to-7-remembrances-and-anecdotes/',
#  '/film/one-minute-for-one-image/',
#  '/film/in-chris-markers-studio/',
#  '/film/the-little-story-of-gwen-from-french-brittany/',
#  '/film/rue-daguerre-in-2005/',
#  '/film/vagabond-remembrances-interviews-notes-and-comments/',
#  '/film/henri-langlois-vu-par/',
#  '/film/some-widows-of-noirmoutier/',
#  '/film/20-little-films/',
#  '/film/more-so-called-caryatids/',
#  '/film/the-story-of-an-old-lady/',
#  '/film/cinevardaphoto/',
#  '/film/christmas-carole/',
#  '/film/agnes-tells-a-sad-and-happy-story/',
#  '/film/souvenirs-and-evocations/',
#  '/film/un-salut-a-henri-langlois/',
#  '/film/the-children-of-museum/',
#  '/film/la-cocotte-dazur/',
#  '/film/la-melangite/',
#  '/film/the-3-lives-of-agnes/',
#  '/film/two-street-artists/',
#  '/film/bord-de-mer-2009/',
#  '/film/bread-painting-accordion/',
#  '/film/daguerreotypes-photographics-objects/',
#  '/film/the-music-festival/',
#  '/film/daguerre-plage/',
#  '/film/musique-et-travellings/',
#  '/film/propos-sur-le-bonheur/',
#  '/film/un-divertissement-et-michel-piccoli/',
#  '/film/a-nathalie-sarraute/',
#  '/film/le-bonheur-reponses-des-fontenaisiens/',
#  '/film/les-deux-femmes-du-bonheur/',
#  '/film/bonheur-nom-propre-ou-concept/',
#  '/film/jean-claude-drouot-revient-a-fontenay-aux/',
#  '/film/trapezistes-et-voltigeurs/']

# %%
first_part_url = "https://letterboxd.com/"

# %%
link_merged=[]

for i in links_of_works:
    link = first_part_url + i
    link_merged.append(link)

link_merged
# Out:
# ['https://letterboxd.com//film/cleo-from-5-to-7/',
#  'https://letterboxd.com//film/vagabond/',
#  'https://letterboxd.com//film/happiness-1965/',
#  'https://letterboxd.com//film/the-gleaners-and-i/',
#  'https://letterboxd.com//film/faces-places/',
#  'https://letterboxd.com//film/the-beaches-of-agnes/',
#  'https://letterboxd.com//film/one-sings-the-other-doesnt/',
#  'https://letterboxd.com//film/black-panthers/',
#  'https://letterboxd.com//film/la-pointe-courte/',
#  'https://letterboxd.com//film/jane-b-by-agnes-v/',
#  'https://letterboxd.com//film/varda-by-agnes/',
#  'https://letterboxd.com//film/along-the-coast/',
#  'https://letterboxd.com//film/uncle-yanco/',
#  'https://letterboxd.com//film/hello-cubans/',
#  'https://letterboxd.com//film/daguerreotypes/',
#  'https://letterboxd.com//film/jacquot-de-nantes/',
#  'https://letterboxd.com//film/one-hundred-and-one-nights/',
#  'https://letterboxd.com//film/women-reply/',
#  'https://letterboxd.com//film/mur-murs/',
#  'https://letterboxd.com//film/kung-fu-master/',
#  'https://letterboxd.com//film/lions-love/',
#  'https://letterboxd.com//film/diary-of-a-pregnant-woman/',
#  'https://letterboxd.com//film/far-from-vietnam/',
#  'https://letterboxd.com//film/documenteur/',
#  'https://letterboxd.com//film/the-creatures/',
#  'https://letterboxd.com//film/fiances-on-the-bridge/',
#  'https://letterboxd.com//film/ulysse/',
#  'https://letterboxd.com//film/the-pleasure-of-love-in-iran/',
#  'https://letterboxd.com//film/youve-got-beautiful-stairs-you-know/',
#  'https://letterboxd.com//film/the-young-girls-turn-25/',
#  'https://letterboxd.com//film/agnes-varda-from-here-to-there/',
#  'https://letterboxd.com//film/tribute-to-zgougou-the-cat/',
#  'https://letterboxd.com//film/the-so-called-caryatids/',
#  'https://letterboxd.com//film/the-gleaners-and-i-two-years-later/',
#  'https://letterboxd.com//film/o-seasons-o-castles/',
#  'https://letterboxd.com//film/pier-paolo-pasolini-agnes-varda-new-york-1967/',
#  'https://letterboxd.com//film/the-world-of-jacques-demy/',
#  'https://letterboxd.com//film/the-vanishing-lion/',
#  'https://letterboxd.com//film/les-3-boutons/',
#  'https://letterboxd.com//film/elsa-the-rose/',
#  'https://letterboxd.com//film/seven-rooms-kitchen-bathroom-for-sale/',
#  'https://letterboxd.com//film/ydessa-the-bears-and-etc/',
#  'https://letterboxd.com//film/nausicaa/',
#  'https://letterboxd.com//film/cleo-from-5-to-7-remembrances-and-anecdotes/',
#  'https://letterboxd.com//film/one-minute-for-one-image/',
#  'https://letterboxd.com//film/in-chris-markers-studio/',
#  'https://letterboxd.com//film/the-little-story-of-gwen-from-french-brittany/',
#  'https://letterboxd.com//film/rue-daguerre-in-2005/',
#  'https://letterboxd.com//film/vagabond-remembrances-interviews-notes-and-comments/',
#  'https://letterboxd.com//film/henri-langlois-vu-par/',
#  'https://letterboxd.com//film/some-widows-of-noirmoutier/',
#  'https://letterboxd.com//film/20-little-films/',
#  'https://letterboxd.com//film/more-so-called-caryatids/',
#  'https://letterboxd.com//film/the-story-of-an-old-lady/',
#  'https://letterboxd.com//film/cinevardaphoto/',
#  'https://letterboxd.com//film/christmas-carole/',
#  'https://letterboxd.com//film/agnes-tells-a-sad-and-happy-story/',
#  'https://letterboxd.com//film/souvenirs-and-evocations/',
#  'https://letterboxd.com//film/un-salut-a-henri-langlois/',
#  'https://letterboxd.com//film/the-children-of-museum/',
#  'https://letterboxd.com//film/la-cocotte-dazur/',
#  'https://letterboxd.com//film/la-melangite/',
#  'https://letterboxd.com//film/the-3-lives-of-agnes/',
#  'https://letterboxd.com//film/two-street-artists/',
#  'https://letterboxd.com//film/bord-de-mer-2009/',
#  'https://letterboxd.com//film/bread-painting-accordion/',
#  'https://letterboxd.com//film/daguerreotypes-photographics-objects/',
#  'https://letterboxd.com//film/the-music-festival/',
#  'https://letterboxd.com//film/daguerre-plage/',
#  'https://letterboxd.com//film/musique-et-travellings/',
#  'https://letterboxd.com//film/propos-sur-le-bonheur/',
#  'https://letterboxd.com//film/un-divertissement-et-michel-piccoli/',
#  'https://letterboxd.com//film/a-nathalie-sarraute/',
#  'https://letterboxd.com//film/le-bonheur-reponses-des-fontenaisiens/',
#  'https://letterboxd.com//film/les-deux-femmes-du-bonheur/',
#  'https://letterboxd.com//film/bonheur-nom-propre-ou-concept/',
#  'https://letterboxd.com//film/jean-claude-drouot-revient-a-fontenay-aux/',
#  'https://letterboxd.com//film/trapezistes-et-voltigeurs/']

# %%
import pandas as pd

movies_and_links={"titles": titles_of_works,
                  "links": link_merged}
table_of_movies=pd.DataFrame(movies_and_links)
table_of_movies
# Out:
#                                                titles  \
# 0                             Cléo from 5 to 7 (1962)
# 1                                     Vagabond (1985)
# 2                                   Le Bonheur (1965)
# 3                           The Gleaners and I (2000)
# 4                                 Faces Places (2017)
# ..                                                ...
# 73      Le Bonheur? Réponses des Fontenaisiens (2006)
# 74                  Les deux femmes du Bonheur (2006)
# 75              Bonheur: nom propre ou concept (2006)
# 76  Jean-Claude Drouot revient à Fontenay-aux-Rose...
# 77                   Trapézistes et voltigeurs (2008)
#
#                                                 links
# 0      https://letterboxd.com//film/cleo-from-5-to-7/
# 1              https://letterboxd.com//film/vagabond/
# 2        https://letterboxd.com//film/happiness-1965/
# 3    https://letterboxd.com//film/the-gleaners-and-i/
# 4          https://letterboxd.com//film/faces-places/
# ..                                                ...
# 73  https://letterboxd.com//film/le-bonheur-repons...
# 74  https://letterboxd.com//film/les-deux-femmes-d...
# 75  https://letterboxd.com//film/bonheur-nom-propr...
# 76  https://letterboxd.com//film/jean-claude-drouo...
# 77  https://letterboxd.com//film/trapezistes-et-vo...
#
# [78 rows x 2 columns]

# %% [markdown]
# Hocam film rantinglerini de çekmek istedim fakat klasik HTML içinde görünmüyor, JSON-LD <scripttype="application/ld+json"> içinde gömülü bir şekilde yazılmış. kod içerisinde bulabildim ama nasıl çekeceğime bakınca beautifulsoup ile falan çekebileceğimi söyledi ama banlanacağımdan korktuğum için vazgeçtim. ama sayfa sayfa gezip kolayca çekebileceğim orijinal ismine bakacağım.
#
#
# //*[@id="film-page-wrapper"]/div[2]/section[1]/div/div/h2/em
# //*[@id="film-page-wrapper"]/div[2]/section[1]/div/div/h2/em

# %%
url='https://letterboxd.com/film/cleo-from-5-to-7/'
html= requests.get(url).content
sel=Selector(text=html)
print("Cleo 5'ten 7'ye", len(sel.xpath("//*")))
# Out:
# Cleo 5'ten 7'ye 1794

# %%
xpath_for_ogtitles_of_works='//*[@id="film-page-wrapper"]/div[2]/section[1]/div/div/h2/em/text()'
ogtitles_of_works=sel.xpath(xpath_for_ogtitles_of_works).extract()
ogtitles_of_works
# Out:
# ['Cléo de 5 à 7']

# %%
og_names=[]

for i in range(len(table_of_movies)):
    url=table_of_movies['links'][i] 
    html=requests.get(url).content
    sel=Selector(text=html)
    names_og=sel.xpath(xpath_for_ogtitles_of_works).getall()
    
    if names_og:  
        for j in names_og:
            og_names.append(j)
    else:
        og_names.append(table_of_movies['titles'][i][:-6])

# %%
og_names
# Out:
# ['Cléo de 5 à 7',
#  'Sans toit ni loi',
#  'Le Bonheur ',
#  'Les Glaneurs et la Glaneuse',
#  'Visages, villages',
#  "Les Plages d'Agnès",
#  "One Sings, the Other Doesn't ",
#  'Black Panthers ',
#  'La Pointe Courte ',
#  'Jane B. by Agnès V. ',
#  'Varda by Agnès ',
#  'Along the Coast ',
#  'Uncle Yanco ',
#  'Hello Cubans ',
#  'Daguerréotypes ',
#  'Jacquot de Nantes ',
#  'One Hundred and One Nights ',
#  'Women Reply ',
#  'Mur Murs ',
#  'Kung-Fu Master! ',
#  'Lions Love ',
#  "L'Opéra-Mouffe",
#  'Loin du Vietnam',
#  'Documenteur ',
#  'The Creatures ',
#  'Fiancés on the Bridge ',
#  'Ulysse ',
#  'The Pleasure of Love in Iran ',
#  "You've Got Beautiful Stairs, You Know... ",
#  'The Young Girls Turn 25 ',
#  'Agnès Varda: From Here to There ',
#  'Tribute to Zgougou the Cat ',
#  'The So-Called Caryatids ',
#  'The Gleaners and I: Two Years Later ',
#  'O Seasons, O Castles ',
#  'Pier Paolo Pasolini - Agnès Varda - New York - 1967 ',
#  'The World of Jacques Demy ',
#  'The Vanishing Lion ',
#  'Les 3 Boutons ',
#  'Elsa the Rose ',
#  'Seven Rooms, Kitchen, Bathroom, for Sale ',
#  'Ydessa, the Bears and etc. ',
#  'Nausicaa ',
#  'Cléo from 5 to 7: Remembrances and Anecdotes ',
#  'One Minute for One Image ',
#  "In Chris Marker's Studio ",
#  'The Little Story of Gwen from French Brittany ',
#  'Rue Daguerre in 2005 ',
#  'Vagabond: Remembrances, Interviews, Notes and Comments ',
#  'Henri Langlois vu par... ',
#  'Some Widows of Noirmoutier ',
#  '20 Little Films ',
#  'More So-called Caryatids ',
#  'The Story of an Old Lady ',
#  'Cinévardaphoto ',
#  'Christmas Carole ',
#  'Agnès Tells a Sad and Happy Story ',
#  'Souvenirs and Evocations ',
#  'Un salut à Henri Langlois ',
#  'The Children of Museum ',
#  "La Cocotte d'azur ",
#  'La Mélangite ',
#  'The 3 Lives of Agnès ',
#  'Two Street Artists ',
#  'Bord de mer ',
#  'Bread, Painting, Accordion ',
#  'Daguerreotypes, Photographics Objects ',
#  'The Music Festival ',
#  'Daguerre-plage ',
#  'Musique et Travellings ',
#  "Propos sur 'Le bonheur' ",
#  'Un divertissement et Michel Piccoli ',
#  'a Nathalie Sarraute ',
#  'Le Bonheur? Réponses des Fontenaisiens ',
#  'Les deux femmes du Bonheur ',
#  'Bonheur: nom propre ou concept ',
#  'Jean-Claude Drouot revient à Fontenay-aux-Roses et parle du',
#  'Trapézistes et voltigeurs ']

# %%
table_of_movies["les noms"]=og_names

# %%
table_of_movies
# Out:
#                                                titles  \
# 0                             Cléo from 5 to 7 (1962)
# 1                                     Vagabond (1985)
# 2                                   Le Bonheur (1965)
# 3                           The Gleaners and I (2000)
# 4                                 Faces Places (2017)
# ..                                                ...
# 73      Le Bonheur? Réponses des Fontenaisiens (2006)
# 74                  Les deux femmes du Bonheur (2006)
# 75              Bonheur: nom propre ou concept (2006)
# 76  Jean-Claude Drouot revient à Fontenay-aux-Rose...
# 77                   Trapézistes et voltigeurs (2008)
#
#                                                 links  \
# 0      https://letterboxd.com//film/cleo-from-5-to-7/
# 1              https://letterboxd.com//film/vagabond/
# 2        https://letterboxd.com//film/happiness-1965/
# 3    https://letterboxd.com//film/the-gleaners-and-i/
# 4          https://letterboxd.com//film/faces-places/
# ..                                                ...
# 73  https://letterboxd.com//film/le-bonheur-repons...
# 74  https://letterboxd.com//film/les-deux-femmes-d...
# 75  https://letterboxd.com//film/bonheur-nom-propr...
# 76  https://letterboxd.com//film/jean-claude-drouo...
# 77  https://letterboxd.com//film/trapezistes-et-vo...
#
#                                              les noms
# 0                                       Cléo de 5 à 7
# 1                                    Sans toit ni loi
# 2                                         Le Bonheur
# 3                         Les Glaneurs et la Glaneuse
# 4                                   Visages, villages
# ..                                                ...
# 73            Le Bonheur? Réponses des Fontenaisiens
# 74                        Les deux femmes du Bonheur
# 75                    Bonheur: nom propre ou concept
# 76  Jean-Claude Drouot revient à Fontenay-aux-Rose...
# 77                         Trapézistes et voltigeurs
#
# [78 rows x 3 columns]

# %% [markdown]
# eğer decadelere göre filtreleyip her decadedeki filmleri kendi başına bir liste oluştursaydık
#
# https://letterboxd.com/director/agnes-varda/decade/1970s/
#
# https://letterboxd.com/director/agnes-varda/decade/1980s/
#
#
# //*[@id="content"]/div/div/section/section[2]/p
#
#
# //*[@id="content"]/div/div/section/div[2]/ul/li[@title]/@title

# %%
decades=["1960s","1970s","1980s","1990s","2000s", "2010s"]

# %%
firstpart="https://letterboxd.com/director/agnes-varda/decade/"

sixties=[]
seventies = []
eighties = []
nineties = []
two_thousands = []
twenty_tens = []

for decade in decades:
    url = firstpart + decade + "/"
    html = requests.get(url).content
    sel = Selector(text=html)
    xpath_for_titles_of_decades = '//*[@id="content"]/div/div/section/div[2]/ul/li[@title]/@title'
    films = sel.xpath(xpath_for_titles_of_decades).extract()
    
    for j in films:
        if decade == "1970s":
            seventies.append(j)
        elif decade == "1980s":
            eighties.append(j)
        elif decade == "1990s":
            nineties.append(j)
        elif decade == "2000s":
            two_thousands.append(j)
        elif decade == "2010s":
            twenty_tens.append(j)
        else:
            sixties.append(j)

# %%
sixties=pd.Series(sixties)
seventies=pd.Series(seventies)
eighties = pd.Series(eighties)
nineties = pd.Series(nineties)
two_thousands = pd.Series(two_thousands)
twenty_tens = pd.Series(twenty_tens)

# %%
display(sixties,seventies, eighties, nineties,two_thousands, twenty_tens)
# Out:
# 0           Cléo from 5 to 7 (1962)
# 1                 Le Bonheur (1965)
# 2             Black Panthers (1968)
# 3                Uncle Yanco (1967)
# 4               Hello Cubans (1963)
# 5                 Lions Love (1969)
# 6           Far from Vietnam (1967)
# 7              The Creatures (1966)
# 8      Fiancés on the Bridge (1962)
# 9              Elsa the Rose (1966)
# 10          Christmas Carole (1966)
# 11    The Children of Museum (1964)
# 12              La Mélangite (1960)
# dtype: object
# 0    One Sings, the Other Doesn't (1977)
# 1                  Daguerréotypes (1975)
# 2                     Women Reply (1975)
# 3    The Pleasure of Love in Iran (1976)
# 4                        Nausicaa (1971)
# dtype: object
# 0                                     Vagabond (1985)
# 1                          Jane B. by Agnès V. (1988)
# 2                                     Mur Murs (1981)
# 3                              Kung-Fu Master! (1988)
# 4                                  Documenteur (1981)
# 5                                       Ulysse (1983)
# 6     You've Got Beautiful Stairs, You Know... (1986)
# 7                      The So-Called Caryatids (1984)
# 8     Seven Rooms, Kitchen, Bathroom, for Sale (1984)
# 9                     One Minute for One Image (1983)
# 10                         a Nathalie Sarraute (1986)
# dtype: object
# 0             Jacquot de Nantes (1991)
# 1    One Hundred and One Nights (1995)
# 2       The Young Girls Turn 25 (1993)
# 3     The World of Jacques Demy (1995)
# dtype: object
# 0                             The Gleaners and I (2000)
# 1                           The Beaches of Agnès (2008)
# 2                     Tribute to Zgougou the Cat (2002)
# 3            The Gleaners and I: Two Years Later (2002)
# 4                             The Vanishing Lion (2003)
# 5                     Ydessa, the Bears and etc. (2004)
# 6     Cléo from 5 to 7: Remembrances and Anecdotes (...
# 7     The Little Story of Gwen from French Brittany ...
# 8                           Rue Daguerre in 2005 (2005)
# 9     Vagabond: Remembrances, Interviews, Notes and ...
# 10                    Some Widows of Noirmoutier (2006)
# 11                      More So-called Caryatids (2005)
# 12                      The Story of an Old Lady (2003)
# 13                                Cinévardaphoto (2004)
# 14             Agnès Tells a Sad and Happy Story (2008)
# 15                      Souvenirs and Evocations (2008)
# 16                                   Bord de mer (2009)
# 17                    Bread, Painting, Accordion (2005)
# 18         Daguerreotypes, Photographics Objects (2005)
# 19                            The Music Festival (2005)
# 20                                Daguerre-plage (2008)
# 21                        Musique et Travellings (2003)
# 22                       Propos sur 'Le bonheur' (2006)
# 23           Un divertissement et Michel Piccoli (2004)
# 24        Le Bonheur? Réponses des Fontenaisiens (2006)
# 25                    Les deux femmes du Bonheur (2006)
# 26                Bonheur: nom propre ou concept (2006)
# 27    Jean-Claude Drouot revient à Fontenay-aux-Rose...
# 28                     Trapézistes et voltigeurs (2008)
# dtype: object
# Series([], dtype: object)

# %%
table_of_movies["decade"] = None

table_of_movies.loc[table_of_movies["titles"].isin(sixties), "decade"] = "60s"
table_of_movies.loc[table_of_movies["titles"].isin(seventies), "decade"] = "70s"
table_of_movies.loc[table_of_movies["titles"].isin(eighties), "decade"] = "80s"
table_of_movies.loc[table_of_movies["titles"].isin(nineties), "decade"] = "90s"
table_of_movies.loc[table_of_movies["titles"].isin(two_thousands), "decade"] = "2000s"
table_of_movies.loc[table_of_movies["titles"].isin(twenty_tens), "decade"] = "2010s"

# %%
table_of_movies
# Out:
#                                                titles  \
# 0                             Cléo from 5 to 7 (1962)
# 1                                     Vagabond (1985)
# 2                                   Le Bonheur (1965)
# 3                           The Gleaners and I (2000)
# 4                                 Faces Places (2017)
# ..                                                ...
# 73      Le Bonheur? Réponses des Fontenaisiens (2006)
# 74                  Les deux femmes du Bonheur (2006)
# 75              Bonheur: nom propre ou concept (2006)
# 76  Jean-Claude Drouot revient à Fontenay-aux-Rose...
# 77                   Trapézistes et voltigeurs (2008)
#
#                                                 links  \
# 0      https://letterboxd.com//film/cleo-from-5-to-7/
# 1              https://letterboxd.com//film/vagabond/
# 2        https://letterboxd.com//film/happiness-1965/
# 3    https://letterboxd.com//film/the-gleaners-and-i/
# 4          https://letterboxd.com//film/faces-places/
# ..                                                ...
# 73  https://letterboxd.com//film/le-bonheur-repons...
# 74  https://letterboxd.com//film/les-deux-femmes-d...
# 75  https://letterboxd.com//film/bonheur-nom-propr...
# 76  https://letterboxd.com//film/jean-claude-drouo...
# 77  https://letterboxd.com//film/trapezistes-et-vo...
#
#                                              les noms decade
# 0                                       Cléo de 5 à 7    60s
# 1                                    Sans toit ni loi    80s
# 2                                         Le Bonheur     60s
# 3                         Les Glaneurs et la Glaneuse  2000s
# 4                                   Visages, villages   None
# ..                                                ...    ...
# 73            Le Bonheur? Réponses des Fontenaisiens   2000s
# 74                        Les deux femmes du Bonheur   2000s
# 75                    Bonheur: nom propre ou concept   2000s
# 76  Jean-Claude Drouot revient à Fontenay-aux-Rose...  2000s
# 77                         Trapézistes et voltigeurs   2000s
#
# [78 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

counts = pd.Series({
    "sixties":len(sixties),
    "seventies": len(seventies),
    "eighties": len(eighties),
    "nineties": len(nineties),
    "two_thousands": len(two_thousands),
    "twenty_tens": len(twenty_tens)
})

counts.plot(kind="bar")
plt.title("Number of Films in Each List")
plt.show()

# %% [markdown]
# * peki input vermek istesek direkt yönetmenlerin isimlerini kurala göre gördiklerinde tüm filmleri çekilsin
# * ve sayfa sayfa gezip filmlerin açıklamalarını da çeksin

# %% [markdown]
# # all combined
#
# içeriye ingilizce karakterler ve isim soy isim arasına tire koyarak bir yönetmen inputu verelim.
#
# dikkat edilemsi gereken yer description her sayfada aynı yere işlenmiş değil tagline'ı olan filmlerde 1. gibi olmayanlarda 2.si olarak işleniyor
#
#     //*[@id="film-page-wrapper"]/div[2]/section[2]/section/div[1]/div/p
#
#     //*[@id="film-page-wrapper"]/div[2]/section[2]/section/div/div[2]/p

# %%
from scrapy import Selector
import requests
import time

director = input("Director (ex: agnes-varda): ")

url = 'https://letterboxd.com/director/' + director+ '/'
html = requests.get(url).content
sel = Selector(text=html)

xpath_for_titles_of_works = '//*[@id="content"]/div/div/section/div[2]/ul/li/div/@data-item-name'
titles_of_works = sel.xpath(xpath_for_titles_of_works).extract()



xpath_for_links_of_works = '//*[@id="content"]/div/div/section/div[2]/ul/li//@data-item-link'
links_of_works = sel.xpath(xpath_for_links_of_works).extract()

link_merged = []
first_part_url = "https://letterboxd.com/"

for i in links_of_works:
    link = first_part_url + i
    link_merged.append(link)




descriptions = []

for i in range(len(link_merged)):
    url = link_merged[i]
    html = requests.get(url).content
    sel = Selector(text=html)

    xpath_desc_1 = '//*[@id="film-page-wrapper"]/div[2]/section[2]/section/div[1]/div/p/text()'
    xpath_desc_2 = '//*[@id="film-page-wrapper"]/div[2]/section[2]/section/div/div[2]/p/text()'

    moviedesc = sel.xpath(xpath_desc_1).extract()
    if not moviedesc:
        moviedesc = sel.xpath(xpath_desc_2).extract()

    if moviedesc:
        descriptions.append(moviedesc[0])
    else:
        descriptions.append("no description available!!!")
# Out:
# Director (ex: agnes-varda):  xavier-dolan

# %%
descriptions[:5]
# Out:
# ['A peculiar neighbor offers hope to a recent widow who is struggling to raise a teenager who is unpredictable and, sometimes, violent.',
#  'Hubert, a brash 17-year-old, is confused and torn by a love-hate relationship with his mother that consumes him more and more each day. After distressing ordeals and tragic episodes, Hubert will find his mother on the banks of Saint Lawrence river, where he grew up, and where a murder will be committed: the murder of childhood.',
#  'The story of an impossible love between a woman named Fred and a transgender woman named Laurence who reveals her inner desire to become her true self.',
#  'Two childhood best friends are asked to share a kiss for the purposes of a student short film. Soon, a lingering doubt sets in, confronting both men with their preferences, threatening the brotherhood of their social circle, and, eventually, changing their lives.',
#  'Louis, a terminally ill writer, returns home after a long absence to tell his family that he is dying.']

# %%
#tekrardan orijinal isimlerini eklemek istersek

og_names=[]

for i in range(len(link_merged)):
    url=link_merged[i] 
    html=requests.get(url).content
    sel=Selector(text=html)

    xpath_for_ogtitles_of_works='//*[@id="film-page-wrapper"]/div[2]/section[1]/div/div/h2/em/text()'

    
    names_og=sel.xpath(xpath_for_ogtitles_of_works).getall()
    
    if names_og:  
        for j in names_og:
            og_names.append(j)
        else:
            og_names.append(titles_of_works[i][:-6])

# %%
og_names
# Out:
# ["J'ai tué ma mère",
#  'I Killed My Mother ',
#  'Juste la fin du monde',
#  "It's Only the End of the World ",
#  'Les amours imaginaires',
#  'Heartbeats ',
#  'Tom à la ferme',
#  'Tom at the Farm ',
#  "La nuit où Laurier Gaudreault s'est réveillé",
#  'The Night Logan Woke Up ']

# %%
import pandas as pd
sellected_director_output=pd.DataFrame({"name":titles_of_works,"original names":og_names,"descriptions":descriptions,"link":link_merged})

# %%
sellected_director_output.head(5)
# Out:
#                                     name                   original names  \
# 0                           Mommy (2014)                 J'ai tué ma mère
# 1              I Killed My Mother (2009)              I Killed My Mother
# 2                Laurence Anyways (2012)            Juste la fin du monde
# 3               Matthias & Maxime (2019)  It's Only the End of the World
# 4  It's Only the End of the World (2016)           Les amours imaginaires
#
#                                         descriptions  \
# 0  A peculiar neighbor offers hope to a recent wi...
# 1  Hubert, a brash 17-year-old, is confused and t...
# 2  The story of an impossible love between a woma...
# 3  Two childhood best friends are asked to share ...
# 4  Louis, a terminally ill writer, returns home a...
#
#                                                 link
# 0           https://letterboxd.com//film/mommy-2014/
# 1   https://letterboxd.com//film/i-killed-my-mother/
# 2     https://letterboxd.com//film/laurence-anyways/
# 3      https://letterboxd.com//film/matthias-maxime/
# 4  https://letterboxd.com//film/its-only-the-end-...
